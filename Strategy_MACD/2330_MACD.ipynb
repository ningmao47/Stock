# %%
from google.colab import drive
drive.mount("/content/drive")

import os
os.chdir('/content/drive/MyDrive/Stock/交易策略')
# Out:
# Mounted at /content/drive

# %%
! pip install backtrader
# Out:
# Collecting backtrader
#   Downloading backtrader-1.9.78.123-py2.py3-none-any.whl.metadata (6.8 kB)
# Downloading backtrader-1.9.78.123-py2.py3-none-any.whl (419 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.5/419.5 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: backtrader
# Successfully installed backtrader-1.9.78.123

# %%
import pandas as pd
import numpy as np

# 使用 FinMind.ipynb 所抓取的基本面資料
df = pd.read_csv("2330_Cal.csv") # 2023-05-01	-> 2026-07-01
df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date").reset_index(drop=True)
df.head()
# Out:
#         date  stock_id  Trading_Volume  Trading_money   open    max    min  \
# 0 2023-05-02      2330        17142380     8572554842  500.0  502.0  496.5
# 1 2023-05-03      2330        12694698     6305914905  496.0  498.0  495.0
# 2 2023-05-04      2330        13699933     6818128036  497.0  499.5  496.0
# 3 2023-05-05      2330         7898012     3949232374  500.0  502.0  498.5
# 4 2023-05-08      2330        11737287     5932968954  509.0  509.0  502.0
#
#    close  spread  Trading_turnover  ...   K   D  RSI_7  RSI_14  BB_Upper  \
# 0  501.0    -1.0             18247  ... NaN NaN    NaN     NaN       NaN
# 1  496.0    -5.0             25658  ... NaN NaN    NaN     NaN       NaN
# 2  498.0     2.0             14801  ... NaN NaN    NaN     NaN       NaN
# 3  500.0     2.0             10944  ... NaN NaN    NaN     NaN       NaN
# 4  504.0     4.0             13709  ... NaN NaN    NaN     NaN       NaN
#
#    BB_Middle  BB_Lower  MACD  MACD_Signal  MACD_Hist
# 0        NaN       NaN   NaN          NaN        NaN
# 1        NaN       NaN   NaN          NaN        NaN
# 2        NaN       NaN   NaN          NaN        NaN
# 3        NaN       NaN   NaN          NaN        NaN
# 4        NaN       NaN   NaN          NaN        NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # MACD_Hist

# %%
import pandas as pd
import backtrader as bt

# 資料處理
df_bt = df.copy()
df_bt = df_bt[['date', 'open', 'max', 'min', 'close', 'MACD', 'MACD_Signal', 'MACD_Hist', 'Trading_Volume']]

df_bt = df_bt.rename(columns={
    "max": "high",
    "min": "low",
    "Trading_Volume": "volume"
})

df_bt = df_bt.dropna().reset_index(drop=True)
df_bt['date'] = pd.to_datetime(df_bt['date'])
df_bt = df_bt.set_index("date")

class PandasData(bt.feeds.PandasData):
    lines = ('macdhist',)
    params = (
        ('datetime', None),
        ('open', 'open'),
        ('high', 'high'),
        ('low', 'low'),
        ('close', 'close'),
        ('volume', 'volume'),
        ('openinterest', -1),
        ('macdhist', 'MACD_Hist'),
    )

# 手續費與證交稅
class TaiwanStockCommission(bt.CommissionInfo):
    params = (
        ("commission", 0.001425),
        ("tax", 0.003),
    )

    def _getcommission(self, size, price, pseudoexec):
        value = abs(size) * price
        commission = value * self.p.commission
        if size < 0:
            commission += value * self.p.tax
        return commission

# 使用ALLIn買法，由於明天的開盤價尚未發生，設計上是使用「當天收盤價」來計算明天要買的股數，但有可能隔天大幅開高，因此保留 5% 現金
class AllInSizer(bt.Sizer):
    params = (("reserve", 0.05),)

    def _getsizing(self, comminfo, cash, data, isbuy):
        if isbuy:
            cash *= (1 - self.p.reserve)
            price = data.close[0]
            cost_per_share = price * (1 + comminfo.p.commission)
            size = int(cash / cost_per_share)
            return max(size, 0)
        return self.broker.getposition(data).size

# MACD 策略
class MACDStrategy(bt.Strategy):
    params = dict(
        stop_loss=0.10, # 停損條件
    )

    def __init__(self):
        self.macdhist = self.data.macdhist
        self.cross = bt.ind.CrossOver(self.macdhist, 0)
        self.order = None
        self.buyprice = None

        # 用於儲存明細紀錄的列表
        self.trades_history = []

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status == order.Completed:
            date = self.data.datetime.date(0)
            exec_price = order.executed.price
            exec_size = abs(order.executed.size)
            exec_value = exec_price * exec_size

            # 手續費與證交稅計算
            comminfo = order.comminfo
            commission = exec_value * comminfo.p.commission
            tax = (exec_value * comminfo.p.tax) if order.issell() else 0.0

            # 取得成交當下的總資產 (用於計算累積報酬率)
            current_value = self.broker.getvalue()
            pnl_pct = (current_value / 1_000_000 - 1) * 100

            if order.isbuy():
                self.buyprice = exec_price
                action = "買入"
            else:
                action = "賣出"

            # 記錄至歷史列表中
            self.trades_history.append({
                "交易日期": date,
                "買賣別": action,
                "成交價": round(exec_price, 2),
                "成交量(股)": exec_size,
                "交易金額": round(exec_value, 2),
                "手續費": round(commission, 2),
                "證交稅": round(tax, 2),
                "總資產": round(current_value, 2),
                "目前報酬率(%)": round(pnl_pct, 2)
            })

            print(f"{date} {action} | 價格:{exec_price:.2f} | 成交量:{exec_size} | 手續費:{commission:.0f} | 證交稅:{tax:.0f}")

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            print(f"{self.data.datetime.date(0)} 交易失敗 : {order.getstatusname()}")

        self.order = None

    def next(self):
        if self.order:
            return

        if self.position:
            loss = (self.data.close[0] - self.buyprice) / self.buyprice

            if loss <= -self.p.stop_loss:
                print(f"{self.data.datetime.date(0)}停損觸發")
                self.order = self.close()
                return

            if self.cross < 0:
                print(f"{self.data.datetime.date(0)}MACD Histogram 正轉負")
                self.order = self.close()
                return
        else:
            if self.cross > 0:
                print(f"{self.data.datetime.date(0)}MACD Histogram 負轉正")
                self.order = self.buy()

    def stop(self):
      # 回測結束時，如果還有持股，強制以最後一天價格賣出
      if self.position:
        print(f"回測結束，強制結算持股：{self.position.size}股")
        self.close()

# 執行回測與表格輸出
cerebro = bt.Cerebro()
cerebro.addstrategy(MACDStrategy)
cerebro.addsizer(AllInSizer, reserve=0.05)

data = PandasData(dataname=df_bt)
cerebro.adddata(data)
cerebro.broker.setcash(1_000_000)

comminfo = TaiwanStockCommission()
cerebro.broker.addcommissioninfo(comminfo)

# 夏普比率與最大回撤
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe', riskfreerate=0.015, annualize=True, timeframe=bt.TimeFrame.Days)
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')

print(f"初始資金：{cerebro.broker.getvalue():,.0f}")
results = cerebro.run()

# 轉為 DataFrame
strat = results[0]
df_trades = pd.DataFrame(strat.trades_history)

final_val = cerebro.broker.getvalue()
pnl_pct = (final_val / 1_000_000 - 1) * 100

# 不下單賣出，而是直接拿最後一天的收盤價 data.close[0] 乘以持股數，當作最後的資產淨值。
if strat.position:
    last_date = strat.data.datetime.date(0)
    pos_size = strat.position.size
    close_price = strat.data.close[0]
    unrealized_value = pos_size * close_price

    # 建立最後一筆紀錄
    unrealized_row = pd.DataFrame([{
        "交易日期": last_date,
        "買賣別": "結算",
        "成交價": round(close_price, 2),
        "成交量(股)": pos_size,
        "交易金額": round(unrealized_value, 2),
        "手續費": 0.0,
        "證交稅": 0.0,
        "總資產": round(final_val, 2),
        "目前報酬率(%)": round(pnl_pct, 2)
    }])

    # 併入原本的交易紀錄表格中
    df_trades = pd.concat([df_trades, unrealized_row], ignore_index=True)

df_trades.to_csv('df_trades.csv', index=False)

# 計算與列印績效指標
print("\n" + "="*30)
print("       策略整體績效評估       ")
print("="*30)

# 最大回撤 (MDD)
'''
最大回撤（Maximum Drawdown, MDD）是指投資組合或交易帳戶在特定期間內，資產淨值從歷史「最高點」跌至「最低點」的最大跌幅。
意義：MDD 數值越小，代表資金曲線越平滑，抗風險能力越強；MDD 越大，代表波動越劇烈，且事後需要極大的漲幅才能回本（例如：帳戶若發生 50% 的最大回撤，則需要 100% 的獲利才能彌補損失）。
合理範圍：一般波段操作與保守配置的策略，最大回撤多落在 10% 至 30% 之間。若超過 30% - 40% 則屬於高風險，需謹慎評估。
'''
mdd = strat.analyzers.drawdown.get_analysis()['max']['drawdown']

# 夏普比率 (Sharpe Ratio)
'''
夏普值 < 0： 報酬率甚至不如放在銀行定存，承擔風險卻不划算。
夏普值 1.0 ~ 1.9： 表現良好，具備不錯的風險調整後報酬。
夏普值 ≥ 2.0： 表現優秀，在控管風險下創造了極佳的收益。
'''
sharpe_info = strat.analyzers.sharpe.get_analysis()
sharpe = sharpe_info.get('sharperatio', None)

# 勝率與賺賠比計算
raw_trades = df_trades[df_trades['買賣別'] != '結算'].copy()
trade_pnls = []

# 將買入與賣出進行配對計算
buy_record = None
for _, row in df_trades.iterrows():
    if row['買賣別'] == '買入':
        buy_record = row
    elif row['買賣別'] in ['賣出', '結算'] and buy_record is not None:
        # 計算包含交易成本後的每筆純利潤
        cost = buy_record['交易金額'] + buy_record['手續費']
        revenue = row['交易金額'] - row['手續費'] - row['證交稅']
        pnl = revenue - cost
        trade_pnls.append(pnl)
        buy_record = None

trade_pnls = np.array(trade_pnls)

if len(trade_pnls) > 0:
    wins = trade_pnls[trade_pnls > 0]
    losses = trade_pnls[trade_pnls < 0]

    win_rate = (len(wins) / len(trade_pnls)) * 100
    avg_win = np.mean(wins) if len(wins) > 0 else 0
    avg_loss = abs(np.mean(losses)) if len(losses) > 0 else 0
    profit_factor = (avg_win / avg_loss) if avg_loss != 0 else np.nan
else:
    win_rate = 0.0
    profit_factor = 0.0

# 總結果
print(f"最終資金：{final_val:,.2f} 元")
print(f"總報酬率：{pnl_pct:.2f} %")
print(f"最大回撤 (MDD)：{mdd:.2f} %")
print(f"夏普比率(Sharpe)：{sharpe:.2f}" if sharpe is not None else "夏普比率 (Sharpe)：無法計算 (波動不足或無交易)")
print(f"總交易次數：{len(trade_pnls)} 次")
print(f"勝率：{win_rate:.2f} %")
print(f"賺賠比：{profit_factor:.2f}")
print("="*30)
print("\n=== 交易紀錄表 ===")
display(df_trades)
df_trades.to_csv('df_trades.csv', index=False)
# Out:
# 初始資金：1,000,000
# 2023-08-24MACD Histogram 負轉正
# 2023-08-25 買入 | 價格:549.00 | 成交量:1682 | 手續費:1316 | 證交稅:0
# 2023-09-08MACD Histogram 正轉負
# 2023-09-11 賣出 | 價格:539.00 | 成交量:1682 | 手續費:1292 | 證交稅:2720
# 2023-09-14MACD Histogram 負轉正
# 2023-09-15 買入 | 價格:549.00 | 成交量:1686 | 手續費:1319 | 證交稅:0
# 2023-09-20MACD Histogram 正轉負
# 2023-09-21 賣出 | 價格:530.00 | 成交量:1686 | 手續費:1273 | 證交稅:2681
# 2023-10-06MACD Histogram 負轉正
# 2023-10-11 買入 | 價格:542.00 | 成交量:1677 | 手續費:1295 | 證交稅:0
# 2023-10-27MACD Histogram 正轉負
# 2023-10-30 賣出 | 價格:531.00 | 成交量:1677 | 手續費:1269 | 證交稅:2671
# 2023-11-03MACD Histogram 負轉正
# 2023-11-06 買入 | 價格:553.00 | 成交量:1584 | 手續費:1248 | 證交稅:0
# 2023-11-27MACD Histogram 正轉負
# 2023-11-28 賣出 | 價格:565.00 | 成交量:1584 | 手續費:1275 | 證交稅:2685
# 2023-12-18MACD Histogram 負轉正
# 2023-12-19 買入 | 價格:588.00 | 成交量:1509 | 手續費:1264 | 證交稅:0
# 2023-12-21MACD Histogram 正轉負
# 2023-12-22 賣出 | 價格:582.00 | 成交量:1509 | 手續費:1251 | 證交稅:2635
# 2023-12-27MACD Histogram 負轉正
# 2023-12-28 買入 | 價格:592.00 | 成交量:1468 | 手續費:1238 | 證交稅:0
# 2024-01-03MACD Histogram 正轉負
# 2024-01-04 賣出 | 價格:580.00 | 成交量:1468 | 手續費:1213 | 證交稅:2554
# 2024-01-19MACD Histogram 負轉正
# 2024-01-22 買入 | 價格:633.00 | 成交量:1354 | 手續費:1221 | 證交稅:0
# 2024-03-19MACD Histogram 正轉負
# 2024-03-20 賣出 | 價格:764.00 | 成交量:1354 | 手續費:1474 | 證交稅:3103
# 2024-04-11MACD Histogram 負轉正
# 2024-04-12 買入 | 價格:823.00 | 成交量:1232 | 手續費:1445 | 證交稅:0
# 2024-04-15MACD Histogram 正轉負
# 2024-04-16 賣出 | 價格:802.00 | 成交量:1232 | 手續費:1408 | 證交稅:2964
# 2024-05-08MACD Histogram 負轉正
# 2024-05-09 買入 | 價格:798.00 | 成交量:1222 | 手續費:1390 | 證交稅:0
# 2024-05-30MACD Histogram 正轉負
# 2024-05-31 賣出 | 價格:838.00 | 成交量:1222 | 手續費:1459 | 證交稅:3072
# 2024-06-07MACD Histogram 負轉正
# 2024-06-11 買入 | 價格:892.00 | 成交量:1161 | 手續費:1476 | 證交稅:0
# 2024-07-02MACD Histogram 正轉負
# 2024-07-03 賣出 | 價格:976.00 | 成交量:1161 | 手續費:1615 | 證交稅:3399
# 2024-07-04MACD Histogram 負轉正
# 2024-07-05 買入 | 價格:1005.00 | 成交量:1102 | 手續費:1578 | 證交稅:0
# 2024-07-17MACD Histogram 正轉負
# 2024-07-18 賣出 | 價格:988.00 | 成交量:1102 | 手續費:1552 | 證交稅:3266
# 2024-08-14MACD Histogram 負轉正
# 2024-08-15 買入 | 價格:945.00 | 成交量:1143 | 手續費:1539 | 證交稅:0
# 2024-09-03MACD Histogram 正轉負
# 2024-09-04 賣出 | 價格:894.00 | 成交量:1143 | 手續費:1456 | 證交稅:3066
# 2024-09-13MACD Histogram 負轉正
# 2024-09-16 買入 | 價格:952.00 | 成交量:1080 | 手續費:1465 | 證交稅:0
# 2024-10-28MACD Histogram 正轉負
# 2024-10-29 賣出 | 價格:1035.00 | 成交量:1080 | 手續費:1593 | 證交稅:3353
# 2024-11-11MACD Histogram 負轉正
# 2024-11-12 買入 | 價格:1060.00 | 成交量:1015 | 手續費:1533 | 證交稅:0
# 2024-11-12MACD Histogram 正轉負
# 2024-11-13 賣出 | 價格:1045.00 | 成交量:1015 | 手續費:1511 | 證交稅:3182
# 2024-12-04MACD Histogram 負轉正
# 2024-12-05 買入 | 價格:1070.00 | 成交量:1010 | 手續費:1540 | 證交稅:0
# 2024-12-20MACD Histogram 正轉負
# 2024-12-23 賣出 | 價格:1065.00 | 成交量:1010 | 手續費:1533 | 證交稅:3227
# 2024-12-23MACD Histogram 負轉正
# 2024-12-24 買入 | 價格:1095.00 | 成交量:991 | 手續費:1546 | 證交稅:0
# 2025-01-02MACD Histogram 正轉負
# 2025-01-03 賣出 | 價格:1080.00 | 成交量:991 | 手續費:1525 | 證交稅:3211
# 2025-01-06MACD Histogram 負轉正
# 2025-01-07 買入 | 價格:1150.00 | 成交量:933 | 手續費:1529 | 證交稅:0
# 2025-01-13MACD Histogram 正轉負
# 2025-01-14 賣出 | 價格:1085.00 | 成交量:933 | 手續費:1443 | 證交稅:3037
# 2025-01-20MACD Histogram 負轉正
# 2025-01-21 買入 | 價格:1115.00 | 成交量:881 | 手續費:1400 | 證交稅:0
# 2025-02-03MACD Histogram 正轉負
# 2025-02-04 賣出 | 價格:1085.00 | 成交量:881 | 手續費:1362 | 證交稅:2868
# 2025-02-07MACD Histogram 負轉正
# 2025-02-10 買入 | 價格:1125.00 | 成交量:850 | 手續費:1363 | 證交稅:0
# 2025-02-10MACD Histogram 正轉負
# 2025-02-11 賣出 | 價格:1110.00 | 成交量:850 | 手續費:1344 | 證交稅:2830
# 2025-03-24MACD Histogram 負轉正
# 2025-03-25 買入 | 價格:989.00 | 成交量:966 | 手續費:1361 | 證交稅:0
# 2025-03-31MACD Histogram 正轉負
# 2025-04-01 賣出 | 價格:929.00 | 成交量:966 | 手續費:1279 | 證交稅:2692
# 2025-04-18MACD Histogram 負轉正
# 2025-04-21 買入 | 價格:844.00 | 成交量:1034 | 手續費:1244 | 證交稅:0
# 2025-04-22MACD Histogram 正轉負
# 2025-04-23 賣出 | 價格:853.00 | 成交量:1034 | 手續費:1257 | 證交稅:2646
# 2025-04-23MACD Histogram 負轉正
# 2025-04-24 買入 | 價格:886.00 | 成交量:1012 | 手續費:1278 | 證交稅:0
# 2025-05-28MACD Histogram 正轉負
# 2025-05-29 賣出 | 價格:986.00 | 成交量:1012 | 手續費:1422 | 證交稅:2993
# 2025-06-09MACD Histogram 負轉正
# 2025-06-10 買入 | 價格:1025.00 | 成交量:969 | 手續費:1415 | 證交稅:0
# 2025-06-23MACD Histogram 正轉負
# 2025-06-24 賣出 | 價格:1045.00 | 成交量:969 | 手續費:1443 | 證交稅:3038
# 2025-06-25MACD Histogram 負轉正
# 2025-06-26 買入 | 價格:1075.00 | 成交量:922 | 手續費:1412 | 證交稅:0
# 2025-07-07MACD Histogram 正轉負
# 2025-07-08 賣出 | 價格:1070.00 | 成交量:922 | 手續費:1406 | 證交稅:2960
# 2025-07-16MACD Histogram 負轉正
# 2025-07-17 買入 | 價格:1130.00 | 成交量:864 | 手續費:1391 | 證交稅:0
# 2025-07-28MACD Histogram 正轉負
# 2025-07-29 賣出 | 價格:1145.00 | 成交量:864 | 手續費:1410 | 證交稅:2968
# 2025-08-12MACD Histogram 負轉正
# 2025-08-13 買入 | 價格:1185.00 | 成交量:833 | 手續費:1407 | 證交稅:0
# 2025-08-15MACD Histogram 正轉負
# 2025-08-18 賣出 | 價格:1170.00 | 成交量:833 | 手續費:1389 | 證交稅:2924
# 2025-09-09MACD Histogram 負轉正
# 2025-09-10 買入 | 價格:1220.00 | 成交量:805 | 手續費:1399 | 證交稅:0
# 2025-10-23MACD Histogram 正轉負
# 2025-10-27 賣出 | 價格:1500.00 | 成交量:805 | 手續費:1721 | 證交稅:3622
# 2025-12-05MACD Histogram 負轉正
# 2025-12-08 買入 | 價格:1465.00 | 成交量:804 | 手續費:1678 | 證交稅:0
# 2025-12-16MACD Histogram 正轉負
# 2025-12-17 賣出 | 價格:1435.00 | 成交量:804 | 手續費:1644 | 證交稅:3461
# 2025-12-23MACD Histogram 負轉正
# 2025-12-24 買入 | 價格:1495.00 | 成交量:768 | 手續費:1636 | 證交稅:0
# 2026-01-30MACD Histogram 正轉負
# 2026-02-02 賣出 | 價格:1750.00 | 成交量:768 | 手續費:1915 | 證交稅:4032
# 2026-02-11MACD Histogram 負轉正
# 2026-02-23 買入 | 價格:1900.00 | 成交量:691 | 手續費:1871 | 證交稅:0
# 2026-03-04MACD Histogram 正轉負
# 2026-03-05 賣出 | 價格:1940.00 | 成交量:691 | 手續費:1910 | 證交稅:4022
# 2026-04-08MACD Histogram 負轉正
# 2026-04-09 買入 | 價格:1945.00 | 成交量:688 | 手續費:1907 | 證交稅:0
# 2026-05-13MACD Histogram 正轉負
# 2026-05-14 賣出 | 價格:2250.00 | 成交量:688 | 手續費:2206 | 證交稅:4644
# 2026-06-01MACD Histogram 負轉正
# 2026-06-02 買入 | 價格:2390.00 | 成交量:650 | 手續費:2214 | 證交稅:0
# 2026-06-08MACD Histogram 正轉負
# 2026-06-09 賣出 | 價格:2305.00 | 成交量:650 | 手續費:2135 | 證交稅:4495
# 2026-06-18MACD Histogram 負轉正
# 2026-06-22 買入 | 價格:2455.00 | 成交量:610 | 手續費:2134 | 證交稅:0
# 2026-06-26MACD Histogram 正轉負
# 2026-06-29 賣出 | 價格:2330.00 | 成交量:610 | 手續費:2025 | 證交稅:4264
# 2026-07-01MACD Histogram 負轉正
#
# ==============================
#        策略整體績效評估
# ==============================
# 最終資金：1,467,121.22 元
# 總報酬率：46.71 %
# 最大回撤 (MDD)：28.17 %
# 夏普比率(Sharpe)：0.68
# 總交易次數：33 次
# 勝率：39.39 %
# 賺賠比：2.59
# ==============================
#
# === 交易紀錄表 ===
#           交易日期 買賣別     成交價  成交量(股)       交易金額      手續費      證交稅         總資產  \
# 0   2023-08-25  買入   549.0    1682   923418.0  1315.87     0.00   993638.13
# 1   2023-09-11  賣出   539.0    1682   906598.0  1291.90  2719.79   977852.43
# 2   2023-09-15  買入   549.0    1686   925614.0  1319.00     0.00   991707.43
# 3   2023-09-21  賣出   530.0    1686   893580.0  1273.35  2680.74   940545.34
# 4   2023-10-11  買入   542.0    1677   908934.0  1295.23     0.00   942604.11
# ..         ...  ..     ...     ...        ...      ...      ...         ...
# 61  2026-05-14  賣出  2250.0     688  1548000.0  2205.90  4644.00  1615887.97
# 62  2026-06-02  買入  2390.0     650  1553500.0  2213.74     0.00  1607174.24
# 63  2026-06-09  賣出  2305.0     650  1498250.0  2135.01  4494.75  1551794.48
# 64  2026-06-22  買入  2455.0     610  1497550.0  2134.01     0.00  1583210.47
# 65  2026-06-29  賣出  2330.0     610  1421300.0  2025.35  4263.90  1467121.22
#
#     目前報酬率(%)
# 0      -0.64
# 1      -2.21
# 2      -0.83
# 3      -5.95
# 4      -5.74
# ..       ...
# 61     61.59
# 62     60.72
# 63     55.18
# 64     58.32
# 65     46.71
#
# [66 rows x 9 columns]

# %% [markdown]
# # cerebro.plot
#
# 1.   第1區塊：藍色代表資產淨值，紅色代表帳戶現金，所以當紅色線突然掉下去的時候，就代表買入股票，上升就代表賣出股票。
# 2.   第2區塊：代表每次賣出的獲利情況，藍色點點表示賺錢，紅色點點表示虧錢。
# 3.   第3區塊：顯示長短均線、買賣點、股價走勢、交易量，從這張圖可以大概看出來買賣的時間點與走勢的相對關係。
# 4.   第4區塊：cross over訊號出現的點

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 12]
plt.rcParams['figure.dpi'] = 150
figs = cerebro.plot(style="candlestick", iplot=False, heightp=0.5)

# %% [markdown]
# # XXXX

# %%
# # 資料處理
# df_bt = df.copy()
# df_bt = df_bt[['date', 'open', 'max', 'min', 'close', 'K', 'D', 'Trading_Volume']]

# df_bt = df_bt.rename(columns={
#     "max": "high",
#     "min": "low",
#     "Trading_Volume": "volume"
# })

# df_bt = df_bt.dropna().reset_index(drop=True)
# df_bt['date'] = pd.to_datetime(df_bt['date'])
# df_bt = df_bt.set_index("date")

# class PandasData(bt.feeds.PandasData):
#     lines = ('k', 'd')
#     params = (
#         ('datetime', None),
#         ('open', 'open'),
#         ('high', 'high'),
#         ('low', 'low'),
#         ('close', 'close'),
#         ('volume', 'volume'),
#         ('openinterest', -1),
#         ('k', 'K'),
#         ('d', 'D'),
#     )

# # 手續費與證交稅
# class TaiwanStockCommission(bt.CommissionInfo):
#     params = (
#         ("commission", 0.001425),
#         ("tax", 0.003),
#     )

#     def _getcommission(self, size, price, pseudoexec):
#         value = abs(size) * price
#         commission = value * self.p.commission
#         if size < 0:
#             commission += value * self.p.tax
#         return commission

# # ALLIn Sizer
# class AllInSizer(bt.Sizer):
#     params = (("reserve", 0.05),)

#     def _getsizing(self, comminfo, cash, data, isbuy):
#         if isbuy:
#             cash *= (1 - self.p.reserve)
#             price = data.close[0]
#             cost_per_share = price * (1 + comminfo.p.commission)
#             size = int(cash / cost_per_share)
#             return max(size, 0)
#         return self.broker.getposition(data).size

# # 修改後的 KD 策略 (新增 K, D 門檻 20 / 80 限制)
# class KDStrategy(bt.Strategy):
#     params = dict(
#         stop_loss=0.10,     # 停損條件：10%
#         kd_low=20,          # 低檔超賣區買入門檻
#         kd_high=80          # 高檔超買區賣出門檻
#     )

#     def __init__(self):
#         self.k = self.data.k
#         self.d = self.data.d
#         self.cross = bt.ind.CrossOver(self.k, self.d)
#         self.order = None
#         self.buyprice = None
#         self.trades_history = []

#     def notify_order(self, order):
#         if order.status in [order.Submitted, order.Accepted]:
#             return

#         if order.status == order.Completed:
#             date = self.data.datetime.date(0)
#             exec_price = order.executed.price
#             exec_size = abs(order.executed.size)
#             exec_value = exec_price * exec_size

#             comminfo = order.comminfo
#             commission = exec_value * comminfo.p.commission
#             tax = (exec_value * comminfo.p.tax) if order.issell() else 0.0

#             current_value = self.broker.getvalue()
#             pnl_pct = (current_value / 1_000_000 - 1) * 100

#             if order.isbuy():
#                 self.buyprice = exec_price
#                 action = "買入"
#             else:
#                 action = "賣出"

#             self.trades_history.append({
#                 "交易日期": date,
#                 "買賣別": action,
#                 "成交價": round(exec_price, 2),
#                 "成交量(股)": exec_size,
#                 "交易金額": round(exec_value, 2),
#                 "手續費": round(commission, 2),
#                 "證交稅": round(tax, 2),
#                 "總資產": round(current_value, 2),
#                 "目前報酬率(%)": round(pnl_pct, 2)
#             })

#             print(f"{date} {action} | 價格:{exec_price:.2f} | 成交量:{exec_size} | 手續費:{commission:.0f} | 證交稅:{tax:.0f}")

#         elif order.status in [order.Canceled, order.Margin, order.Rejected]:
#             print(f"{self.data.datetime.date(0)} 交易失敗 : {order.getstatusname()}")

#         self.order = None

#     def next(self):
#         if self.order:
#             return

#         # 持有部位時的出場判斷
#         if self.position:
#             loss = (self.data.close[0] - self.buyprice) / self.buyprice

#             # 停損機制
#             if loss <= -self.p.stop_loss:
#                 print(f"{self.data.datetime.date(0)} 停損觸發")
#                 self.order = self.close()
#                 return

#             # KD 死亡交叉 且 KD > 80 (高檔超買區賣出)
#             # if self.cross < 0 and self.k[0] > self.p.kd_high and self.d[0] > self.p.kd_high:
#             #     print(f"{self.data.datetime.date(0)} KD高檔死亡交叉(K:{self.k[0]:.1f}, D:{self.d[0]:.1f})")
#             #     self.order = self.close()
#             #     return

#             # KD > 80 (高檔超買區賣出)
#             if self.k[0] > self.p.kd_high and self.d[0] > self.p.kd_high:
#                 print(f"{self.data.datetime.date(0)} KD高檔(K:{self.k[0]:.1f}, D:{self.d[0]:.1f})")
#                 self.order = self.close()
#                 return

#         # 空手時的進場判斷
#         else:
#             # KD 黃金交叉 且 KD < 20 (低檔超賣區買入)
#             # if self.cross > 0 and self.k[0] < self.p.kd_low and self.d[0] < self.p.kd_low:
#             #     print(f"{self.data.datetime.date(0)} KD低檔黃金交叉(K:{self.k[0]:.1f}, D:{self.d[0]:.1f})")
#             #     self.order = self.buy()

#             # KD < 20 (低檔超賣區買入)
#             if self.k[0] < self.p.kd_low and self.d[0] < self.p.kd_low:
#                 print(f"{self.data.datetime.date(0)} KD低檔(K:{self.k[0]:.1f}, D:{self.d[0]:.1f})")
#                 self.order = self.buy()

#     def stop(self):
#         if self.position:
#             print(f"回測結束，強制結算持股：{self.position.size}股")
#             self.close()

# # 執行回測與分析
# cerebro = bt.Cerebro()
# cerebro.addstrategy(KDStrategy)
# cerebro.addsizer(AllInSizer, reserve=0.05)

# data = PandasData(dataname=df_bt)
# cerebro.adddata(data)
# cerebro.broker.setcash(1_000_000)

# comminfo = TaiwanStockCommission()
# cerebro.broker.addcommissioninfo(comminfo)

# cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe', riskfreerate=0.015, annualize=True, timeframe=bt.TimeFrame.Days)
# cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')

# print(f"初始資金：{cerebro.broker.getvalue():,.0f}")
# results = cerebro.run()

# # 轉為 DataFrame 與績效計算
# strat = results[0]
# df_trades = pd.DataFrame(strat.trades_history)

# final_val = cerebro.broker.getvalue()
# pnl_pct = (final_val / 1_000_000 - 1) * 100

# if strat.position:
#     last_date = strat.data.datetime.date(0)
#     pos_size = strat.position.size
#     close_price = strat.data.close[0]
#     unrealized_value = pos_size * close_price

#     unrealized_row = pd.DataFrame([{
#         "交易日期": last_date,
#         "買賣別": "結算",
#         "成交價": round(close_price, 2),
#         "成交量(股)": pos_size,
#         "交易金額": round(unrealized_value, 2),
#         "手續費": 0.0,
#         "證交稅": 0.0,
#         "總資產": round(final_val, 2),
#         "目前報酬率(%)": round(pnl_pct, 2)
#     }])

#     df_trades = pd.concat([df_trades, unrealized_row], ignore_index=True)

# df_trades.to_csv('df_trades.csv', index=False)

# # 印出報告
# print("\n" + "="*30)
# print("策略整體績效評估")
# print("="*30)

# mdd = strat.analyzers.drawdown.get_analysis()['max']['drawdown']
# sharpe_info = strat.analyzers.sharpe.get_analysis()
# sharpe = sharpe_info.get('sharperatio', None)

# trade_pnls = []
# buy_record = None
# for _, row in df_trades.iterrows():
#     if row['買賣別'] == '買入':
#         buy_record = row
#     elif row['買賣別'] in ['賣出', '結算'] and buy_record is not None:
#         cost = buy_record['交易金額'] + buy_record['手續費']
#         revenue = row['交易金額'] - row['手續費'] - row['證交稅']
#         pnl = revenue - cost
#         trade_pnls.append(pnl)
#         buy_record = None

# trade_pnls = np.array(trade_pnls)

# if len(trade_pnls) > 0:
#     wins = trade_pnls[trade_pnls > 0]
#     losses = trade_pnls[trade_pnls < 0]
#     win_rate = (len(wins) / len(trade_pnls)) * 100
#     avg_win = np.mean(wins) if len(wins) > 0 else 0
#     avg_loss = abs(np.mean(losses)) if len(losses) > 0 else 0
#     profit_factor = (avg_win / avg_loss) if avg_loss != 0 else np.nan
# else:
#     win_rate = 0.0
#     profit_factor = 0.0

# print(f"最終資金：{final_val:,.2f} 元")
# print(f"總報酬率：{pnl_pct:.2f} %")
# print(f"最大回撤 (MDD)：{mdd:.2f} %")
# print(f"夏普比率(Sharpe)：{sharpe:.2f}" if sharpe is not None else "夏普比率 (Sharpe)：無法計算 (波動不足或無交易)")
# print(f"總交易次數：{len(trade_pnls)} 次")
# print(f"勝率：{win_rate:.2f} %")
# print(f"賺賠比：{profit_factor:.2f}")
# print("="*30)

# print("\n=== 交易紀錄表 ===")
# display(df_trades)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 12]
plt.rcParams['figure.dpi'] = 150
figs = cerebro.plot(style="candlestick", iplot=False, heightp=0.5)

# %% [markdown]
# # 參考資料
#
# https://ithelp.ithome.com.tw/m/articles/10242427
#
# https://vocus.cc/article/67f8ebfbfd8978000177661f
#
# https://finlab.finance/blog/what-is-backtesting
